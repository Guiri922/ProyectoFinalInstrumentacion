# %%
import scipy

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
file = pd.read_csv("log_20260521_194322_approx_65bpm.csv")
file

# %%
adc = file["ADC"]
adc

# %%
ts = pd.Series(adc[:100])
ts.plot()

# %%
time = file["Fecha y Hora"]

# %%
peaks = scipy.signal.find_peaks(adc)
